# %%
import plotly.express as px
import pandas as pd
from datetime import datetime
#df_csv=pd.read_csv("D:/MaestriaEA/Analisis de Datos/ultimaCalse/Metro_Interstate_Traffic_Volume.csv",delimiter=",")

# %%
df_csv
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        None  288.28      0.0      0.0          40        Clouds
# 1        None  289.36      0.0      0.0          75        Clouds
# 2        None  289.58      0.0      0.0          90        Clouds
# 3        None  290.13      0.0      0.0          90        Clouds
# 4        None  291.14      0.0      0.0          75        Clouds
# ...       ...     ...      ...      ...         ...           ...
# 48199    None  283.45      0.0      0.0          75        Clouds
# 48200    None  282.76      0.0      0.0          90        Clouds
# 48201    None  282.73      0.0      0.0          90  Thunderstorm
# 48202    None  282.09      0.0      0.0          90        Clouds
# 48203    None  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 0            scattered clouds  2012-10-02 09:00:00            5545
# ...

# %%
df_csv['date_time']= pd.to_datetime(df_csv['date_time'],format='%Y-%m-%d %H:%M:%S')

# %%
df_csv['date_time'][43000:43900]
# Out:
# 43000   2018-04-07 03:00:00
# 43001   2018-04-07 04:00:00
# 43002   2018-04-07 05:00:00
# 43003   2018-04-07 06:00:00
# 43004   2018-04-07 07:00:00
#                 ...
# 43895   2018-05-08 00:00:00
# 43896   2018-05-08 01:00:00
# 43897   2018-05-08 02:00:00
# 43898   2018-05-08 03:00:00
# 43899   2018-05-08 04:00:00
# Name: date_time, Length: 900, dtype: datetime64[ns]

# %%
df_csv3=df_csv[43000:43900]
df_csv3
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 43000    None  263.02      0.0      0.0          40         Snow
# 43001    None  262.82      0.0      0.0           1         Snow
# 43002    None  262.49      0.0      0.0           1        Clear
# 43003    None  262.15      0.0      0.0           1         Snow
# 43004    None  261.89      0.0      0.0           1        Clear
# ...       ...     ...      ...      ...         ...          ...
# 43895    None  294.49      0.0      0.0           1        Clear
# 43896    None  293.62      0.0      0.0           1        Clear
# 43897    None  292.35      0.0      0.0           1        Clear
# 43898    None  292.48      0.0      0.0           1         Rain
# 43899    None  292.72      0.0      0.0           1        Clear
#
#       weather_description           date_time  traffic_volume
# 43000          light snow 2018-04-07 03:00:00             381
# ...

# %%
df_csv2=df_csv[40255:]
df_csv2
# Out:
#              holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 40255  New Years Day  249.36      0.0      0.0           1         Clear
# 40256           None  249.08      0.0      0.0           1         Clear
# 40257           None  248.86      0.0      0.0           1         Clear
# 40258           None  248.72      0.0      0.0           1         Clear
# 40259           None  248.43      0.0      0.0           1         Clear
# ...              ...     ...      ...      ...         ...           ...
# 48199           None  283.45      0.0      0.0          75        Clouds
# 48200           None  282.76      0.0      0.0          90        Clouds
# 48201           None  282.73      0.0      0.0          90  Thunderstorm
# 48202           None  282.09      0.0      0.0          90        Clouds
# 48203           None  282.12      0.0      0.0          90        Clouds
#
#           weather_description           date_time  traffic_volume
# ...

# %%
fig = px.line(df_csv3, x="date_time", y=df_csv3.columns[-1],title="Volumen de tráfico interestatal metropolitano")
fig.update_layout(width=1500, height=300)
fig.show()
# Out:
# <div>                            <div id="57d82411-1bbd-4f6b-b8c0-704e3004709b" class="plotly-graph-div" style="height:300px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57d82411-1bbd-4f6b-b8c0-704e3004709b")) {                    Plotly.newPlot(                        "57d82411-1bbd-4f6b-b8c0-704e3004709b",                        [{"hovertemplate":"date_time=%{x}<br>traffic_volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2018-04-07T03:00:00","2018-04-07T04:00:00","2018-04-07T05:00:00","2018-04-07T06:00:00","2018-04-07T07:00:00","2018-04-07T08:00:00","2018-04-07T09:00:00","2018-04-07T10:00:00","2018-04-07T11:00:00","2018-04-07T12:00:00","2018-04-07T13:00:
# ...

# %%
fig = px.line(df_csv2, x="date_time", y=df_csv2.columns[-1],title="Volumen de tráfico interestatal metropolitano")
fig.update_layout(width=1500, height=300)
fig.show()
# Out:
# <div>                            <div id="1ed05dc6-be91-4c8c-8c81-1f2f50adf4dc" class="plotly-graph-div" style="height:300px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ed05dc6-be91-4c8c-8c81-1f2f50adf4dc")) {                    Plotly.newPlot(                        "1ed05dc6-be91-4c8c-8c81-1f2f50adf4dc",                        [{"hovertemplate":"date_time=%{x}<br>traffic_volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2018-01-01T00:00:00","2018-01-01T01:00:00","2018-01-01T02:00:00","2018-01-01T03:00:00","2018-01-01T04:00:00","2018-01-01T05:00:00","2018-01-01T06:00:00","2018-01-01T07:00:00","2018-01-01T08:00:00","2018-01-01T09:00:00","2018-01-01T10:00:00","2018-01-01T11
# ...
